# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('data_daun_mangga.csv')
display(df)
import seaborn as sns
import pandas as pd

df = pd.read_csv('data_daun_mangga.csv')
display(df)
# Out:
#        pj   lb  jn
# 0    14.5  4.0   1
# 1    19.0  6.0   1
# 2    18.0  4.0   1
# 3    18.0  4.0   1
# 4    20.5  5.0   1
# ..    ...  ...  ..
# 295  21.0  6.0   3
# 296  18.5  6.0   3
# 297  16.0  7.0   3
# 298  17.0  5.5   3
# 299  22.0  7.0   3
#
# [300 rows x 3 columns]
#        pj   lb  jn
# 0    14.5  4.0   1
# 1    19.0  6.0   1
# 2    18.0  4.0   1
# 3    18.0  4.0   1
# 4    20.5  5.0   1
# ..    ...  ...  ..
# 295  21.0  6.0   3
# 296  18.5  6.0   3
# 297  16.0  7.0   3
# 298  17.0  5.5   3
# 299  22.0  7.0   3
#
# [300 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['pj'].plot(kind='hist', bins=20, title='pj')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['lb'].plot(kind='hist', bins=20, title='lb')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.describe()
deskripsi_data = df.describe()
deskripsi_data.to_excel('deskripsi_data_daun_mangga.xlsx', index=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 24))

for i, col_name in enumerate(df.columns[:-1]):
    plt.subplot(6, 2, i + 1)
    sns.boxplot(y=df[col_name], showmeans=True, meanprops={"marker":"s", "markerfacecolor":"white", "markeredgecolor":"black"})
    plt.axhline(df[col_name].median(), color='red', linestyle='dashed', linewidth=1, label='Median')
    plt.title(f'Boxplot of Variable {col_name}')
    plt.ylabel(f'Values of {col_name}')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data_daun_mangga.csv')
df.head()
# Out:
#      pj   lb  jn
# 0  14.5  4.0   1
# 1  19.0  6.0   1
# 2  18.0  4.0   1
# 3  18.0  4.0   1
# 4  20.5  5.0   1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-63-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
df.shape #(rows,cols)
# Out:
# (300, 3)

# %%
df.dtypes
# Out:
# pj    float64
# lb    float64
# jn      int64
# dtype: object

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
sns.set(style="whitegrid")
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.scatterplot(x='pj', y='lb', data=df, ax=axes[0], color='green')
axes[0].set_title('Basic Syntax vs. Variable and Data Type')
axes[0].set_xlabel('Basic Syntax')
axes[0].set_ylabel('Variable and Data Type')

sns.scatterplot(x='pj', y='lb', data=df, ax=axes[1], color='red')
axes[1].set_title('Variable and Data Type vs. Input Output')
axes[1].set_xlabel('Variable and Data')
axes[1].set_ylabel('Input Output')

sns.scatterplot(x='pj', y='lb', data=df, ax=axes[2])
axes[2].set_title('Input Output vs. Operator')
axes[2].set_xlabel('Input Output')
axes[2].set_ylabel('Operator')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(16, 8))
ax = sns.countplot(x='pj', data=df, palette='Set3')

plt.title('Distribusi Proyek Akhir Mahasiswa', fontsize=18, fontweight='bold')
plt.xlabel('Jenis Proyek (pj)', fontsize=14)
plt.ylabel('Jumlah (lb)', fontsize=14)
plt.xticks(rotation=65, ha='right', fontsize=10)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.0f}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom',
                fontsize=9, color='black',
                xytext=(0, 4),
                textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-70-80148a0a7696>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='pj', data=df, palette='Set3')

# %%
X=df.drop(['jn'],axis=1)
y=df['jn']
print(X)
print(y)
# Out:
#        pj   lb
# 0    14.5  4.0
# 1    19.0  6.0
# 2    18.0  4.0
# 3    18.0  4.0
# 4    20.5  5.0
# ..    ...  ...
# 295  21.0  6.0
# 296  18.5  6.0
# 297  16.0  7.0
# 298  17.0  5.5
# 299  22.0  7.0
#
# [300 rows x 2 columns]
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 295    3
# 296    3
# 297    3
# 298    3
# 299    3
# Name: jn, Length: 300, dtype: int64

# %%
from sklearn.preprocessing import  StandardScaler

scl =StandardScaler()
X_scaled = scl.fit_transform(X)
print(X_scaled)
# Out:
# [[-6.60333803e-01 -7.20053417e-01]
#  [ 5.15877615e-01  3.48275095e-01]
#  [ 2.54497300e-01 -7.20053417e-01]
#  [ 2.54497300e-01 -7.20053417e-01]
#  [ 9.07948088e-01 -1.85889161e-01]
#  [-6.88301497e-03 -4.52971289e-01]
#  [-5.29643645e-01 -7.20053417e-01]
#  [ 1.23807143e-01 -7.20053417e-01]
#  [ 1.03863825e+00 -1.85889161e-01]
#  [-5.29643645e-01 -1.85889161e-01]
#  [ 2.54497300e-01 -2.92722012e-01]
#  [ 7.77257931e-01 -4.52971289e-01]
#  [ 1.23807143e-01 -6.13220566e-01]
#  [ 1.03863825e+00 -6.13220566e-01]
#  [ 2.54497300e-01 -7.20053417e-01]
#  [-8.52971095e-02 -7.20053417e-01]
#  [-5.29643645e-01 -3.46138438e-01]
#  [ 4.63601552e-01 -8.80302694e-01]
#  [-1.05240428e+00 -1.04055197e+00]
#  [-3.56165530e+00  4.78183842e+00]
#  [ 7.15310796e-02 -2.56398843e-02]
#  [-4.25091519e-01 -6.66636992e-01]
#  [-5.29643645e-01 -9.33719120e-01]
#  [-1.70585506e+00 -1.14738482e+00]
#  [-6.08057740e-01 -1.04055197e+00]
#  [-6.88301497e-03 -8.80302694e-01]
#  [-1.36606065e+00 -1.09396840e+00]
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,test_size=.2,random_state=42)
print(X_train[:, 0])
print("===============")
print(X_train[:, 1])
# Out:
# [ 0.2544973  -0.39895349 -0.52964365 -0.39895349 -0.79102396  0.38518746
#  -0.52964365 -1.18309443  0.30677336 -0.00688301  1.03863825  0.51587762
#  -0.26826333  0.38518746 -1.18309443 -0.52964365 -0.13757317 -0.97399018
#   0.90794809 -0.26826333 -1.70585506  1.56139888 -3.5616553   0.2544973
#   0.12380714  2.60692014  0.51587762 -1.57516491 -0.08529711  0.2544973
#   0.38518746 -0.13757317 -1.05240428 -0.13757317 -1.05240428 -0.52964365
#  -0.13757317  0.64656777  0.12380714  0.2544973  -0.13757317  0.07153108
#  -0.84330002  1.43070872  1.14319037  0.51587762  0.64656777 -1.05240428
#  -0.00688301 -0.52964365  0.64656777  0.51587762 -0.92171412  0.2544973
#   0.2544973   1.69208903  2.47622998 -0.52964365 -0.26826333 -0.92171412
#   0.12380714  0.12380714  1.43070872 -0.00688301  3.78313156 -0.60805774
#   0.72498187  0.77725793  0.77725793 -0.52964365 -0.39895349  1.69208903
#   0.77725793 -1.31378459 -0.13757317 -0.79102396 -1.31378459  0.2544973
# ...

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_train[:, 0], y=X_train[:, 1], hue=y_train, palette='Set2', s=40)
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score # Import classification_report and accuracy_score

svm_mdl = SVC(random_state=42, probability=True)
clf = svm_mdl.fit(X_train, y_train)


y_pred = svm_mdl.predict(X_test)
y_pred

print("===================================================")

conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix for Support Vector Machines:')
print(conf_matrix)

print("__"*50 )

print("num of True Positive :",conf_matrix[1][1])
print("num of True Negative :",conf_matrix[0][0])
print("num of False Positive :",conf_matrix[0][1])
print("num of False Negative :",conf_matrix[1][0])

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='OrRd', cbar=False)
plt.title('Confusion Matrix for Support Vector Machines')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

classification_rep = classification_report(y_test, y_pred) # Now classification_report is defined
print('\nClassification Report for Support Vector Machines:')
print(classification_rep)

accuracy = accuracy_score(y_test, y_pred) # Now accuracy_score is defined
print(f'Accuracy of Support Vector Machines : {accuracy*100:.2f} %')
# Out:
# ...
# Confusion Matrix for Support Vector Machines:
# [[ 0  0  0  0]
#  [16  2  4  0]
#  [ 4  8  4  0]
#  [ 1  3 18  0]]
# ____________________________________________________________________________________________________
# num of True Positive : 2
# num of True Negative : 0
# num of False Positive : 0
# num of False Negative : 16
# Classification Report for Support Vector Machines:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.15      0.09      0.11        22
#            2       0.15      0.25      0.19        16
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.10        60
#    macro avg       0.08      0.09      0.08        60
# weighted avg       0.10      0.10      0.09        60
#
# Accuracy of Support Vector Machines : 10.00 %
# ...

# %%
from sklearn.naive_bayes import GaussianNB

naive_bayes_mdl = GaussianNB()

naive_bayes_mdl.fit(X_train, y_train)

y_pred= naive_bayes_mdl.predict(X_test)


conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix for Naive Bayes:')
print(conf_matrix)

print("__"*50 )

print("num of True Positive :",conf_matrix[1][1])
print("num of True Negative :",conf_matrix[0][0])
print("num of False Positive :",conf_matrix[0][1])
print("num of False Negative :",conf_matrix[1][0])

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='inferno', cbar=False)
plt.title('Confusion Matrix for Naive Bayes')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

classification_rep = classification_report(y_test, y_pred)
print('\nClassification Report for Naive Bayes:')
print(classification_rep)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy of Naive Bayes : {accuracy*100:.2f} %')
# Out:
# Confusion Matrix for Naive Bayes:
# [[ 0  0  0  0]
#  [10  2 10  0]
#  [ 5  4  7  0]
#  [ 2  2 18  0]]
# ____________________________________________________________________________________________________
# num of True Positive : 2
# num of True Negative : 0
# num of False Positive : 0
# num of False Negative : 10
# Classification Report for Naive Bayes:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.25      0.09      0.13        22
#            2       0.20      0.44      0.27        16
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.15        60
#    macro avg       0.11      0.13      0.10        60
# weighted avg       0.14      0.15      0.12        60
#
# Accuracy of Naive Bayes : 15.00 %
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree_mdl = DecisionTreeClassifier(random_state=42)

decision_tree_mdl.fit(X_train, y_train)

y_pred = decision_tree_mdl.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix for DecisionTree :')
print(conf_matrix)

print("__"*50 )

print("num of True Positive :",conf_matrix[1][1])
print("num of True Negative :",conf_matrix[0][0])
print("num of False Positive :",conf_matrix[0][1])
print("num of False Negative :",conf_matrix[1][0])

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Purples', cbar=False)
plt.title('Confusion Matrix for DecisionTree')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

classification_rep = classification_report(y_test, y_pred)
print('\nClassification Report for DecisionTree:')
print(classification_rep)


from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy of DecisionTree : {accuracy*100:.2f} %')
# Out:
# Confusion Matrix for DecisionTree :
# [[ 0  0  0  0]
#  [16  2  4  0]
#  [ 4  6  6  0]
#  [ 4 11  7  0]]
# ____________________________________________________________________________________________________
# num of True Positive : 2
# num of True Negative : 0
# num of False Positive : 0
# num of False Negative : 16
# Classification Report for DecisionTree:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.11      0.09      0.10        22
#            2       0.35      0.38      0.36        16
#            3       0.00      0.00      0.00        22
#
#     accuracy                           0.13        60
#    macro avg       0.11      0.12      0.12        60
# weighted avg       0.13      0.13      0.13        60
#
# Accuracy of DecisionTree : 13.33 %
# ...

# %%
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
from sklearn.neighbors import KNeighborsClassifier
knn_mdl = KNeighborsClassifier()
knn_mdl.fit(X_train, y_train)
y_pred= knn_mdl.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)

print('Confusion Matrix for 1)	K-Nearest Neighbors:')
print(conf_matrix)
print("__"*50 )
print("num of True Positive :",conf_matrix[1][1])
print("num of True Negative :",conf_matrix[0][0])
print("num of False Positive :",conf_matrix[0][1])
print("num of False Negative :",conf_matrix[1][0])

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', cbar=False)
plt.title('Confusion Matrix for k-Nearest Neighbors')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

classification_rep = classification_report(y_test, y_pred)
print('\nClassification Report for k-Nearest Neighbors:')
print(classification_rep)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy of K-Nearest Neighbors : {accuracy*100:.2f} %')
# Out:
# Confusion Matrix for 1)	K-Nearest Neighbors:
# [[15  2  5]
#  [ 4  9  3]
#  [ 3  4 15]]
# ____________________________________________________________________________________________________
# num of True Positive : 9
# num of True Negative : 15
# num of False Positive : 2
# num of False Negative : 4
# Classification Report for k-Nearest Neighbors:
#               precision    recall  f1-score   support
#
#            1       0.68      0.68      0.68        22
#            2       0.60      0.56      0.58        16
#            3       0.65      0.68      0.67        22
#
#     accuracy                           0.65        60
#    macro avg       0.64      0.64      0.64        60
# weighted avg       0.65      0.65      0.65        60
#
# Accuracy of K-Nearest Neighbors : 65.00 %

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

log_cls = LogisticRegression(random_state=42)
log_cls.fit(X_train, y_train)

y_pred = log_cls.predict(X_test)
X_train_df = pd.DataFrame(X, columns=df.columns[:-1])
X_train_df['combined_feature'] = X_train_df['pj'] + X_train_df['lb']
X_train_df = pd.DataFrame(X_train, columns=df.columns[:-1])
X_train_df['combined_feature'] = X_train_df['pj'] + X_train_df['lb']
plt.figure(figsize=(8, 6))
sns.scatterplot(x=X_train_df['combined_feature'], y=y_train, hue=y_train, palette='Set2', s=40)
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report

df = pd.read_csv('data_daun_mangga.csv')
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
y_train = y_train - 1
y_test = y_test - 1

model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dense(32, activation='relu'),
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_pred_classes = y_pred_classes + 1
y_test = y_test + 1

print(classification_report(y_test, y_pred_classes))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.1046 - loss: 9.6415 - val_accuracy: 0.1250 - val_loss: 8.0995
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1577 - loss: 7.4071 - val_accuracy: 0.1667 - val_loss: 6.0911
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1662 - loss: 6.9073 - val_accuracy: 0.1875 - val_loss: 5.3353
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.2605 - loss: 5.0577 - val_accuracy: 0.2708 - val_loss: 4.5074
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3228 - loss: 4.8084 - val_accuracy: 0.3750 - val_loss: 3.9360
# Epoch 6/50
# ...
